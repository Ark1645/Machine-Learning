# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn import linear_model

# %%
df=pd.read_csv("/content/drive/MyDrive/homeprices.csv")
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
reg = linear_model.LinearRegression()
reg.fit(df[{'area'}],df.price)
# Out:
# <ipython-input-8-9a11dc3f4685>:2: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   reg.fit(df[{'area'}],df.price)
# LinearRegression()

# %%
# %matplotlib inline
plt.xlabel("Area")
plt.ylabel("Price")
plt.scatter(df.area,df.price,color="red",marker='+')
plt.plot(df.area,reg.predict(df[['area']]),color='blue')

# %%
reg.predict([[3300]])

# %%
reg.coef_

# %%
reg.intercept_

# %%
#y=m*x+c
135.78767123*3300+180616.43835616432

# %%
reg.predict([[5000]])

# %%
reg.coef_

# %%
reg.intercept_

# %%
135.78767123*5000+180616.43835616432

# %%
d=pd.read_csv("/content/drive/MyDrive/areas.csv")

# %%
p=reg.predict(d)

# %%
d['Prices']=p

# %%
d

# %%
from matplotlib import pyplot as plt
d['area'].plot(kind='hist', bins=20, title='area')
plt.gca().spines[['top', 'right',]].set_visible(False)
